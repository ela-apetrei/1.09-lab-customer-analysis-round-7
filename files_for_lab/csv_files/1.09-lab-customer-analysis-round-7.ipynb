# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import pickle as pkl

import warnings
warnings.filterwarnings('ignore') ### 02 - Getting Data

# %% [markdown]
# ### 01 - Problem (case study)
# - Data Description.
# - Goal.

# %% [markdown]
# ### 02 - Getting Data
# - Read the `.csv` file.

# %%
data = pd.read_csv('marketing_customer_analysis.csv')
data
# Out:
#      Customer       State  Customer Lifetime Value Response  Coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      Education Effective To Date EmploymentStatus Gender  Income  ...  \
# ...

# %% [markdown]
# ### 03 - Cleaning/Wrangling/EDA
#
# - Change headers names.
# - Deal with NaN values.
# - Categorical Features.
# - Numerical Features.
# - Exploration.

# %%
#lower cases
data.columns = data.columns.str.lower()
data
# Out:
#      customer       state  customer lifetime value response  coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      education effective to date employmentstatus gender  income  ...  \
# ...

# %%
# standardized column names will be meaninfull strings, lower cased and with '_' instead of 'spaces'
data.columns = [data.columns[i].lower().replace(' ', '_') for i in range(len(data.columns)) ]
 
data
# Out:
#      customer       state  customer_lifetime_value response  coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      education effective_to_date employmentstatus gender  income  ...  \
# ...

# %%
# renaming columns
data = data.rename(columns={'unnamed:_0':'id'})
data
# Out:
#      customer       state  customer_lifetime_value response  coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      education effective_to_date employmentstatus gender  income  ...  \
# ...

# %%
data = data.set_index('customer')

# %%
#checking NaN values
data.isnull().values.any()
# Out:
# False

# %%
data
# Out:
#                state  customer_lifetime_value response  coverage education  \
# customer
# BU79786   Washington              2763.519279       No     Basic  Bachelor
# QZ44356      Arizona              6979.535903       No  Extended  Bachelor
# AI49188       Nevada             12887.431650       No   Premium  Bachelor
# WW63253   California              7645.861827       No     Basic  Bachelor
# HB64268   Washington              2813.692575       No     Basic  Bachelor
# ...              ...                      ...      ...       ...       ...
# LA72316   California             23405.987980       No     Basic  Bachelor
# PK87824   California              3096.511217      Yes  Extended   College
# TD14365   California              8163.890428       No  Extended  Bachelor
# UP19263   California              7524.442436       No  Extended   College
# Y167826   California              2611.836866       No  Extended   College
#
# ...

# %%
categorical = data.select_dtypes(include='object')
categorical
# Out:
#                state response  coverage education effective_to_date  \
# customer
# BU79786   Washington       No     Basic  Bachelor           2/24/11
# QZ44356      Arizona       No  Extended  Bachelor           1/31/11
# AI49188       Nevada       No   Premium  Bachelor           2/19/11
# WW63253   California       No     Basic  Bachelor           1/20/11
# HB64268   Washington       No     Basic  Bachelor            2/3/11
# ...              ...      ...       ...       ...               ...
# LA72316   California       No     Basic  Bachelor           2/10/11
# PK87824   California      Yes  Extended   College           2/12/11
# TD14365   California       No  Extended  Bachelor            2/6/11
# UP19263   California       No  Extended   College            2/3/11
# Y167826   California       No  Extended   College           2/14/11
#
#          employmentstatus gender location_code marital_status     policy_type  \
# customer
# ...

# %%
# Checking if parametrization is needed
## for column in categorical.columns:
#print(column, categorical[column].unique())

# %%
numerical = data.select_dtypes(include='number')
numerical
# Out:
#           customer_lifetime_value  income  monthly_premium_auto  \
# customer
# BU79786               2763.519279   56274                    69
# QZ44356               6979.535903       0                    94
# AI49188              12887.431650   48767                   108
# WW63253               7645.861827       0                   106
# HB64268               2813.692575   43836                    73
# ...                           ...     ...                   ...
# LA72316              23405.987980   71941                    73
# PK87824               3096.511217   21604                    79
# TD14365               8163.890428       0                    85
# UP19263               7524.442436   21941                    96
# Y167826               2611.836866       0                    77
#
#           months_since_last_claim  months_since_policy_inception  \
# customer
# BU79786                        32                              5
# ...

# %%
numerical.apply(lambda x: round(x,2))
# Out:
#           customer_lifetime_value  income  monthly_premium_auto  \
# customer
# BU79786                   2763.52   56274                    69
# QZ44356                   6979.54       0                    94
# AI49188                  12887.43   48767                   108
# WW63253                   7645.86       0                   106
# HB64268                   2813.69   43836                    73
# ...                           ...     ...                   ...
# LA72316                  23405.99   71941                    73
# PK87824                   3096.51   21604                    79
# TD14365                   8163.89       0                    85
# UP19263                   7524.44   21941                    96
# Y167826                   2611.84       0                    77
#
#           months_since_last_claim  months_since_policy_inception  \
# customer
# BU79786                        32                              5
# ...

# %%
data.corr()
# Out:
#                                customer_lifetime_value    income  \
# customer_lifetime_value                       1.000000  0.024366
# income                                        0.024366  1.000000
# monthly_premium_auto                          0.396262 -0.016665
# months_since_last_claim                       0.011517 -0.026715
# months_since_policy_inception                 0.009418 -0.000875
# number_of_open_complaints                    -0.036343  0.006408
# number_of_policies                            0.021955 -0.008656
# total_claim_amount                            0.226451 -0.355254
#
#                                monthly_premium_auto  months_since_last_claim  \
# customer_lifetime_value                    0.396262                 0.011517
# income                                    -0.016665                -0.026715
# monthly_premium_auto                       1.000000                 0.005026
# ...

# %% [markdown]
# ### 04 - Processing Data / Improving the data
#
# - use the concept of multicollinearity and remove insignificant variables
# - use a different method of scaling the numerical variables
# - use a different ratio of train test split
# - use the transformation on numerical columns which align it more towards a normal distribution

# %%
corr_data = data.select_dtypes([np.number])
correlations_matrix = corr_data.corr()  # method='spearman'
correlations_matrix
# Out:
#                                customer_lifetime_value    income  \
# customer_lifetime_value                       1.000000  0.024366
# income                                        0.024366  1.000000
# monthly_premium_auto                          0.396262 -0.016665
# months_since_last_claim                       0.011517 -0.026715
# months_since_policy_inception                 0.009418 -0.000875
# number_of_open_complaints                    -0.036343  0.006408
# number_of_policies                            0.021955 -0.008656
# total_claim_amount                            0.226451 -0.355254
#
#                                monthly_premium_auto  months_since_last_claim  \
# customer_lifetime_value                    0.396262                 0.011517
# income                                    -0.016665                -0.026715
# monthly_premium_auto                       1.000000                 0.005026
# ...

# %%
mask = np.zeros_like(correlations_matrix)

mask[np.triu_indices_from(mask)] = True # optional, to hide repeat half of the matrix

fig, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(correlations_matrix, mask=mask, annot=True)
plt.show()

# %%
data_corr = data.corr()
data_corr
# Out:
#                                customer_lifetime_value    income  \
# customer_lifetime_value                       1.000000  0.024366
# income                                        0.024366  1.000000
# monthly_premium_auto                          0.396262 -0.016665
# months_since_last_claim                       0.011517 -0.026715
# months_since_policy_inception                 0.009418 -0.000875
# number_of_open_complaints                    -0.036343  0.006408
# number_of_policies                            0.021955 -0.008656
# total_claim_amount                            0.226451 -0.355254
#
#                                monthly_premium_auto  months_since_last_claim  \
# customer_lifetime_value                    0.396262                 0.011517
# income                                    -0.016665                -0.026715
# monthly_premium_auto                       1.000000                 0.005026
# ...

# %%
# let's check for outliers
sns.boxplot(x=data['monthly_premium_auto'], whis = 1.5 )
plt.show()

# %%
data[data['total_claim_amount'] > 700]
# Out:
#                state  customer_lifetime_value response  coverage  \
# customer
# QZ44356      Arizona              6979.535903       No  Extended
# US89481   California              3946.372085       No   Premium
# IL19217   California              3939.006370      Yes  Extended
# FR46645   California              4293.997319       No   Premium
# ML29312       Oregon              4499.493252       No  Extended
# ...              ...                      ...      ...       ...
# SJ86522   California              6827.044423       No     Basic
# UU42868   California              5619.689084      Yes   Premium
# JR41742   California              3622.872124       No     Basic
# RX91025   California             19872.262000       No   Premium
# TD14365   California              8163.890428       No  Extended
#
#                      education effective_to_date employmentstatus gender  \
# customer
# QZ44356               Bachelor           1/31/11       Unemployed      F
# ...

# %%
# removing outliers
# first we find our interquartile range
iqr = np.percentile(data['total_claim_amount'],75) - np.percentile(data['total_claim_amount'],25) # data['IC1'].quantile(0.75)
iqr
# Out:
# 275.25659425

# %%
# the stantard threshold to consider is by adding (upper) or subtracting (lower) 1.5 x IQR
upper_limit = np.percentile(data['total_claim_amount'],75) + 1.5*iqr
lower_limit = np.percentile(data['total_claim_amount'],25) - 1.5*iqr
upper_limit, lower_limit
# Out:
# (960.3997301249999, -140.62664687499995)

# %%
#filtering out the outliers
data = data[(data['total_claim_amount']>lower_limit) & (data['total_claim_amount']<upper_limit)]
data
# Out:
#                state  customer_lifetime_value response  coverage education  \
# customer
# BU79786   Washington              2763.519279       No     Basic  Bachelor
# AI49188       Nevada             12887.431650       No   Premium  Bachelor
# WW63253   California              7645.861827       No     Basic  Bachelor
# HB64268   Washington              2813.692575       No     Basic  Bachelor
# OC83172       Oregon              8256.297800      Yes     Basic  Bachelor
# ...              ...                      ...      ...       ...       ...
# LA72316   California             23405.987980       No     Basic  Bachelor
# PK87824   California              3096.511217      Yes  Extended   College
# TD14365   California              8163.890428       No  Extended  Bachelor
# UP19263   California              7524.442436       No  Extended   College
# Y167826   California              2611.836866       No  Extended   College
#
# ...

# %%
#Dealing with customer_lifetime_value by replacing the -inf values by 0 after we take logarithm of 0
def log_lmbda(x):
    return np.log(x) if np.isfinite(np.log(x)) else np.NAN

def log_lmbda(x):
    if np.isfinite(np.log(x)):
        return np.log(x)
    else:
        return np.NAN

log_lmbda = lambda x: np.log(x) if np.isfinite(np.log(x)) else np.NAN

# %%
data['customer_lifetime_value'] = data['customer_lifetime_value'].apply(log_lmbda)

data['customer_lifetime_value'] = data['customer_lifetime_value'].fillna(np.mean(data['customer_lifetime_value']))

sns.distplot(data['customer_lifetime_value'])
plt.show()

# %%
sns.boxplot(data['customer_lifetime_value'])
# Out:
# <AxesSubplot:xlabel='customer_lifetime_value'>

# %% [markdown]
# ## THIS IS FROM THE LAST ROUND

# %%
#visualizing the data
for column in data.select_dtypes(np.number).columns:
    sns.distplot(data[column])
    plt.show()

# %%
#dropping the outliers
def remove_outliers(data, threshold=1.5, in_columns=data.select_dtypes(np.number).columns, skip_columns=[]):
    for column in in_columns:
        if column not in skip_columns:
            upper = np.percentile(data[column],75)
            lower = np.percentile(data[column],25)
            iqr = upper - lower
            upper_limit = upper + threshold * iqr
            lower_limit = lower - threshold * iqr
            data = data[(data[column]>lower_limit) & (data[column]<upper_limit)]
    return data

# %%
data = data.copy()
data = remove_outliers(data, threshold=2, skip_columns=['number_of_open_complaints'])
data
# Out:
#                state  customer_lifetime_value response  coverage education  \
# customer
# BU79786   Washington                 7.924260       No     Basic  Bachelor
# AI49188       Nevada                 9.464008       No   Premium  Bachelor
# WW63253   California                 8.941920       No     Basic  Bachelor
# HB64268   Washington                 7.942253       No     Basic  Bachelor
# OC83172       Oregon                 9.018732      Yes     Basic  Bachelor
# ...              ...                      ...      ...       ...       ...
# LA72316   California                10.060747       No     Basic  Bachelor
# PK87824   California                 8.038031      Yes  Extended   College
# TD14365   California                 9.007476       No  Extended  Bachelor
# UP19263   California                 8.925912       No  Extended   College
# Y167826   California                 7.867809       No  Extended   College
#
# ...

# %%
data = remove_outliers(data, threshold=1.5, in_columns=['total_claim_amount', 'customer_lifetime_value'])
data
# Out:
#                state  customer_lifetime_value response  coverage education  \
# customer
# BU79786   Washington                 7.924260       No     Basic  Bachelor
# AI49188       Nevada                 9.464008       No   Premium  Bachelor
# WW63253   California                 8.941920       No     Basic  Bachelor
# HB64268   Washington                 7.942253       No     Basic  Bachelor
# OC83172       Oregon                 9.018732      Yes     Basic  Bachelor
# ...              ...                      ...      ...       ...       ...
# LA72316   California                10.060747       No     Basic  Bachelor
# PK87824   California                 8.038031      Yes  Extended   College
# TD14365   California                 9.007476       No  Extended  Bachelor
# UP19263   California                 8.925912       No  Extended   College
# Y167826   California                 7.867809       No  Extended   College
#
# ...

# %%
## X-y defining;
X = data.drop('total_claim_amount', axis=1)
y = data['total_claim_amount']

# %%
## X-y split for Normalizer;
X_num = X.select_dtypes(include = np.number)
X_cat = X.select_dtypes(include = np.object)

X_num
# Out:
#           customer_lifetime_value  income  monthly_premium_auto  \
# customer
# BU79786                  7.924260   56274                    69
# AI49188                  9.464008   48767                   108
# WW63253                  8.941920       0                   106
# HB64268                  7.942253   43836                    73
# OC83172                  9.018732   62902                    69
# ...                           ...     ...                   ...
# LA72316                 10.060747   71941                    73
# PK87824                  8.038031   21604                    79
# TD14365                  9.007476       0                    85
# UP19263                  8.925912   21941                    96
# Y167826                  7.867809       0                    77
#
#           months_since_last_claim  months_since_policy_inception  \
# customer
# BU79786                        32                              5
# ...

# %%
#Encoding
encoder = OneHotEncoder(handle_unknown='error', drop='first')
encoder.fit(X_cat)
# Out:
# OneHotEncoder(drop='first')

# %%
#assigning the encoded values of categorical columns to x_cat
x_cat = encoder.transform(X_cat).toarray()

# %%
# getting the column names
cols = list(X_num.columns)
cols.extend(list([g for i in encoder.categories_ for g in i[1:]]))

# %%
cols
# Out:
# ['customer_lifetime_value',
#  'income',
#  'monthly_premium_auto',
#  'months_since_last_claim',
#  'months_since_policy_inception',
#  'number_of_open_complaints',
#  'number_of_policies',
#  'California',
#  'Nevada',
#  'Oregon',
#  'Washington',
#  'Yes',
#  'Extended',
#  'Premium',
#  'College',
#  'Doctor',
#  'High School or Below',
#  'Master',
#  '1/10/11',
#  '1/11/11',
#  '1/12/11',
#  '1/13/11',
#  '1/14/11',
#  '1/15/11',
#  '1/16/11',
#  '1/17/11',
#  '1/18/11',
#  '1/19/11',
#  '1/2/11',
#  '1/20/11',
#  '1/21/11',
#  '1/22/11',
#  '1/23/11',
#  '1/24/11',
#  '1/25/11',
#  '1/26/11',
#  '1/27/11',
#  '1/28/11',
#  '1/29/11',
#  '1/3/11',
#  '1/30/11',
#  '1/31/11',
#  '1/4/11',
#  '1/5/11',
#  '1/6/11',
#  '1/7/11',
#  '1/8/11',
#  '1/9/11',
#  '2/1/11',
#  '2/10/11',
#  '2/11/11',
#  '2/12/11',
#  '2/13/11',
#  '2/14/11',
#  '2/15/11',
#  '2/16/11',
#  '2/17/11',
#  '2/18/11',
#  '2/19/11',
#  '2/2/11',
#  '2/20/11',
#  '2/21/11',
#  '2/22/11',
#  '2/23/11',
# ...

# %%
# Normalize (numerical).
transformer = Normalizer()
transformer.fit(X_num)

with open('transformer.pkl', 'wb') as file:
    pkl.dump(transformer, file)

with open('transformer.pkl', 'rb') as file:
    transformer = pkl.load(file)

x_normalized = transformer.transform(X_num)
#pd.DataFrame(x_normalized)
x_normalized.shape
# Out:
# (8321, 7)
